# %% [markdown]
# <a href="https://colab.research.google.com/github/FunkEngine2023/FunkEngine2023.github.io/blob/Funky_Notebooks/FunkEngine_TavernAI_GPU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title
# !sudo lsof -i -P -n

# %%
#@title
# !rm -rf /TavernAIColab/tai.txt
# !rm -rf /TavernAIColab/taipid.txt

# %%
#@title
# !nohup lt --port 8000 > lt.txt 2>&1 & echo -n $! > ltpid.txt
time.sleep(1)
lturl = open("lt.txt").readline().strip().split("your url is: ")[1]
print(lturl)
ltpid = open("ltpid.txt").readline()
print(ltpid)

# %%
#@title
# !nohup lt --port 8000 > lt.txt 2>&1 & echo -n $! > ltpid.txt
time.sleep(1)
lturl = open("lt.txt").readline().strip().split("your url is: ")[1]
print(lturl)
tunpid = open("ltpid.txt").readline()
print(tunpid)

# %%
#@title colors { display-mode: "form" }
class colors:
  GRY = '\033[90m'
  RED = '\033[91m'
  GRN = '\033[92m'
  YEL = '\033[93m'
  BLU = '\033[94m'
  PUR = '\033[95m'
  CYN = '\033[96m'
  BWT = '\033[97m'
  END = '\033[0m'
  BLD = '\033[1m'
  UND = '\033[4m'
  BLK = '\033[30m'
  WHT = '\033[37m'
  BK = '\033[30m'
  RD = '\033[31m'
  GN = '\033[32m'
  YL = '\033[33m'
  BU = '\033[34m'
  PR = '\033[35m'
  CN = '\033[36m'
  WT = '\033[37m'
  GY = '\033[90m'


print(format(colors.BLK) + "moo" + format(colors.END))
print(format(colors.RED) + "moo" + format(colors.END))
print(format(colors.YEL) + "moo" + format(colors.END))
print(format(colors.GRN) + "moo" + format(colors.END))
print(format(colors.CYN) + "moo" + format(colors.END))
print(format(colors.BLU) + "moo" + format(colors.END))
print(format(colors.PUR) + "moo" + format(colors.END))
print(format(colors.GRY) + "moo" + format(colors.END))
print(format(colors.WHT) + "moo" + format(colors.END))

print(format(colors.BLD) + "moo" + format(colors.END))
print(format(colors.UND) + "moo" + format(colors.END))

print(format(colors.BK) + "moo" + format(colors.END))
print(format(colors.RD) + "moo" + format(colors.END))
print(format(colors.YL) + "moo" + format(colors.END))
print(format(colors.GN) + "moo" + format(colors.END))
print(format(colors.CN) + "moo" + format(colors.END))
print(format(colors.BU) + "moo" + format(colors.END))
print(format(colors.PR) + "moo" + format(colors.END))
print(format(colors.GY) + "moo" + format(colors.END))
print(format(colors.WT) + "moo" + format(colors.END))




print(format(colors.BLK) + (colors.BLD) + "moo" + format(colors.END))
print(format(colors.RED) + (colors.BLD) + "moo" + format(colors.END))
print(format(colors.YEL) + (colors.BLD) + "moo" + format(colors.END))
print(format(colors.GRN) + (colors.BLD) + "moo" + format(colors.END))
print(format(colors.CYN) + (colors.BLD) + "moo" + format(colors.END))
print(format(colors.BLU) + (colors.BLD) + "moo" + format(colors.END))
print(format(colors.PUR) + (colors.BLD) + "moo" + format(colors.END))
print(format(colors.GRY) + (colors.BLD) + "moo" + format(colors.END))
print(format(colors.WHT) + (colors.BLD) + "moo" + format(colors.END))

print(format(colors.BLD) + "moo" + format(colors.END))
print(format(colors.UND) + "moo" + format(colors.END))

print(format(colors.BK) + (colors.BLD) + "moo" + format(colors.END))
print(format(colors.RD) + (colors.BLD) + "moo" + format(colors.END))
print(format(colors.YL) + (colors.BLD) + "moo" + format(colors.END))
print(format(colors.GN) + (colors.BLD) + "moo" + format(colors.END))
print(format(colors.CN) + (colors.BLD) + "moo" + format(colors.END))
print(format(colors.BU) + (colors.BLD) + "moo" + format(colors.END))
print(format(colors.PR) + (colors.BLD) + "moo" + format(colors.END))
print(format(colors.GY) + (colors.BLD) + "moo" + format(colors.END))
print(format(colors.WT) + (colors.BLD) + "moo" + format(colors.END))




print(format(colors.BLK) + (colors.UND) + "moo" + format(colors.END))
print(format(colors.RED) + (colors.UND) + "moo" + format(colors.END))
print(format(colors.YEL) + (colors.UND) + "moo" + format(colors.END))
print(format(colors.GRN) + (colors.UND) + "moo" + format(colors.END))
print(format(colors.CYN) + (colors.UND) + "moo" + format(colors.END))
print(format(colors.BLU) + (colors.UND) + "moo" + format(colors.END))
print(format(colors.PUR) + (colors.UND) + "moo" + format(colors.END))
print(format(colors.GRY) + (colors.UND) + "moo" + format(colors.END))
print(format(colors.WHT) + (colors.UND) + "moo" + format(colors.END))

print(format(colors.BLD) + "moo" + format(colors.END))
print(format(colors.UND) + "moo" + format(colors.END))

print(format(colors.BK) + (colors.UND) + "moo" + format(colors.END))
print(format(colors.RD) + (colors.UND) + "moo" + format(colors.END))
print(format(colors.YL) + (colors.UND) + "moo" + format(colors.END))
print(format(colors.GN) + (colors.UND) + "moo" + format(colors.END))
print(format(colors.CN) + (colors.UND) + "moo" + format(colors.END))
print(format(colors.BU) + (colors.UND) + "moo" + format(colors.END))
print(format(colors.PR) + (colors.UND) + "moo" + format(colors.END))
print(format(colors.GY) + (colors.UND) + "moo" + format(colors.END))
print(format(colors.WT) + (colors.UND) + "moo" + format(colors.END))




print(format(colors.BLK) + (colors.BLD) + (colors.UND) + "moo" + format(colors.END))
print(format(colors.RED) + (colors.BLD) + (colors.UND) + "moo" + format(colors.END))
print(format(colors.YEL) + (colors.BLD) + (colors.UND) + "moo" + format(colors.END))
print(format(colors.GRN) + (colors.BLD) + (colors.UND) + "moo" + format(colors.END))
print(format(colors.CYN) + (colors.BLD) + (colors.UND) + "moo" + format(colors.END))
print(format(colors.BLU) + (colors.BLD) + (colors.UND) + "moo" + format(colors.END))
print(format(colors.PUR) + (colors.BLD) + (colors.UND) + "moo" + format(colors.END))
print(format(colors.GRY) + (colors.BLD) + (colors.UND) + "moo" + format(colors.END))
print(format(colors.WHT) + (colors.BLD) + (colors.UND) + "moo" + format(colors.END))

print(format(colors.BLD) + "moo" + format(colors.END))
print(format(colors.UND) + "moo" + format(colors.END))

print(format(colors.BK) + (colors.BLD) + (colors.UND) + "moo" + format(colors.END))
print(format(colors.RD) + (colors.BLD) + (colors.UND) + "moo" + format(colors.END))
print(format(colors.YL) + (colors.BLD) + (colors.UND) + "moo" + format(colors.END))
print(format(colors.GN) + (colors.BLD) + (colors.UND) + "moo" + format(colors.END))
print(format(colors.CN) + (colors.BLD) + (colors.UND) + "moo" + format(colors.END))
print(format(colors.BU) + (colors.BLD) + (colors.UND) + "moo" + format(colors.END))
print(format(colors.PR) + (colors.BLD) + (colors.UND) + "moo" + format(colors.END))
print(format(colors.GY) + (colors.BLD) + (colors.UND) + "moo" + format(colors.END))
print(format(colors.WT) + (colors.BLD) + (colors.UND) + "moo" + format(colors.END))

# %%
#@title coloris { display-mode: "form" }
class colors:
  GRY = '\033[1;90m'
  RED = '\033[1;91m'
  GRN = '\033[1;92m'
  YEL = '\033[1;93m'
  BLU = '\033[1;94m'
  PUR = '\033[1;95m'
  CYN = '\033[1;96m'
  BWT = '\033[1;97m'
  END = '\033[1;0m'
  BLD = '\033[1m'
  UND = '\033[1;4m'
  BLK = '\033[1;30m'
  WHT = '\033[1;37m'
  BK = '\033[1;30m'
  RD = '\033[1;31m'
  GN = '\033[1;32m'
  YL = '\033[1;33m'
  BU = '\033[1;34m'
  PR = '\033[1;35m'
  CN = '\033[1;36m'
  WT = '\033[1;37m'
  GY = '\033[1;90m'


print(format(colors.BLK) + "moo" + format(colors.END))
print(format(colors.RED) + "moo" + format(colors.END))
print(format(colors.YEL) + "moo" + format(colors.END))
print(format(colors.GRN) + "moo" + format(colors.END))
print(format(colors.CYN) + "moo" + format(colors.END))
print(format(colors.BLU) + "moo" + format(colors.END))
print(format(colors.PUR) + "moo" + format(colors.END))
print(format(colors.GRY) + "moo" + format(colors.END))
print(format(colors.WHT) + "moo" + format(colors.END))

print(format(colors.BLD) + "moo" + format(colors.END))
print(format(colors.UND) + "moo" + format(colors.END))

print(format(colors.BK) + "moo" + format(colors.END))
print(format(colors.RD) + "moo" + format(colors.END))
print(format(colors.YL) + "moo" + format(colors.END))
print(format(colors.GN) + "moo" + format(colors.END))
print(format(colors.CN) + "moo" + format(colors.END))
print(format(colors.BU) + "moo" + format(colors.END))
print(format(colors.PR) + "moo" + format(colors.END))
print(format(colors.GY) + "moo" + format(colors.END))
print(format(colors.WT) + "moo" + format(colors.END))

# %%
#@title <h1> V-Tap this if you play on Mobile-V </h1> { run: "auto", vertical-output: true, form-width: "100%", display-mode: "form" }
#Taken from KoboldAI colab
# %%html
<audio loop autoplay src="https://henk.tech/colabkobold/silence.m4a" controls></audio><br/><br/><br/><b>The silent audio track will hopefully convince your phone browser that you're listening to music, and will keep this tab active.</b><br/><b>Hit the button up here, then go pick a model and start TavernAI as normal in the next cell down. (Uses only 13MB of data)</b><br/><br/><br/><br/><br/><video autoplay src="https://github.com/FunkEngine2023/FunkEngine2023.github.io/raw/Funky_Notebooks/NFM.mp4"></video><br/>

# %% [markdown]
# https://colab.research.google.com/github/TavernAI/TavernAI/blob/main/colab/GPU.ipynb<br>
#
# Works with:<br>
# KoboldAI https://github.com/KoboldAI/KoboldAI-Client<br>
# <br>
# **Links**<br>
# TavernAI Github https://github.com/TavernAI/TavernAI<br>
# TavernAI Discord https://discord.gg/zmK2gmr45t<br>
# TavernAI Boosty https://boosty.to/tavernai
# <pre>
#  Tavern.AI/ \ /  ^   ^ ^ ^    ~~~~ ^ \     /  ^ ^   ^ ^/ ^  ^ \/^  ^    \
#          /^ ^\ ^  ^ ^   ^ ^  ~~   ^   \   /  ^  ^ ^   / ^ ^  ^/   ^ ^    \
#         /^ ^ ^\^   ^ ^ ^   _||____   ^ \ /  ^  ^ ^   /       /  ^  ^  ^   \
#  /\ /\ /\   ^  \  /\ /\   /\\\\\\\\   ^ \  ^ /\ /\ /\   /\ /\ /\  ^ ^  ^/\
# //\\/\\/\\   ^  \//\\/\\ /__\\\\\\\\  _, \  //\\/\\/\\ //\\/\\/\\  ^ ^ //\\
# //\\/\\/\\       //\\/\\ |__|_|_|__|   \__, //\\/\\/\\ //\\/\\/\\     ///\\\
#  || || (@＾◡＾)(≖ ‸ ≖*) ( ←_← )\| /|   /\ \ヽ(°ㅂ°╬) |( Ψ▼ｰ▼)∈ (O_O; )  |||
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ~~~~~ ~~~~~ ~~~~~ ~~~~~  ~~~~~ ~~
# </pre>
# **Launch Instructions**<br>
# 1. ## Horde users as well as NovelAI and OpenAI users load slightly faster now... Pick your endpoint from the model list.
# 2. ## The URL needed to access the TavernAI interface will appear nearly right away. It may be 40-90 seconds after that that the link will actually connect.(If you're loading an actual model.) You can putz around in tavern while Kobold-AI loads the model, browse Chara Cloud, etc well before the Kobold-AI link drops into the console.
# 3. ## After initialization, an identical TavernAI link will appear again when server.js is actually spun-up. As will the Kobold-AI link(s) for the UIs etc.
#
# **Faq**<br>
# * Q: I do not get a TavernAI link.
# * A: You **will** get a link. Very infrequently a link is defective, re-run the cell.

# %%
#@title
#!ps --help all
# !ps -ef --width 1024

# %%
#@title
# !curl ipecho.net/plain

# %%
#@title
# %cd /content/drive/MyDrive/LLM/KoboldAI
# !cp -r /content/KoboldAI-Client/cache/models--KoboldAI--OPT-6B-nerys-v2 /content/drive/MyDrive/LLM/KoboldAI

# %%
#@title
# !./tmp/cloudflared-linux-amd64 tunnel --url http://127.0.0.1:5000 --metrics 127.0.0.1:8099

# %%
#@title <h1>TavernAI</h1> { form-width: "44%", display-mode: "form" }
#@markdown #<- Click For Start  (≖ ‸ ≖ ✿)
# %cd /
# !npm install -g localtunnel
import os
import subprocess
import time
import sys
import threading
import shutil
from google.colab import drive
# !nohup lt --port 8000 > lt.txt 2>&1 & echo -n $! > ltpid.txt
time.sleep(1)
lturl = open("lt.txt").readline().strip().split("your url is: ")[1]
print(lturl)
tunpid = open("ltpid.txt").readline()
print(ltpid)
# !rm -rf /content/sample_data
# !rm -rf /content/.config/
# %cd /content/
#Select-your-X!
Model = "Erebus 6B" #@param ["Kobold Horde", "NovelAI", "OpenAI", "Without Model", "Erebus 6B", "Nerybus 6B", "Nerys V2 6B", ""] {allow-input: true}
Version = "Official" 
KoboldAI_Provider = "Cloudflare" #@param ["Cloudflare", "Localtunnel"]
use_google_drive = True #@param {type:"boolean"}
Provider = KoboldAI_Provider

# !nvidia-smi -pm 1
# !nvidia-smi -pl 69
# !nvidia-smi -c 3
# !nvidia-smi

#Env
Revision = ""
url = "nope"
colab_type = 2
if Model == "Kobold Horde":
    colab_type = 3
if Model == "Without Model":
    colab_type = 5
if Model == "OpenAI":
    colab_type = 5
if Model == "NovelAI":
    colab_type = 5
# %env colab=colab_type
if use_google_drive:
  drive.mount('/content/drive/')
  if not os.path.exists("/content/drive/MyDrive/TavernAI/"):
    os.mkdir("/content/drive/MyDrive/TavernAI/")
  if not os.path.exists("/content/drive/MyDrive/TavernAI/characters/"):
    os.mkdir("/content/drive/MyDrive/TavernAI/characters/")
  if not os.path.exists("/content/drive/MyDrive/TavernAI/chats/"):
    os.mkdir("/content/drive/MyDrive/TavernAI/chats/")
  if not os.path.exists("/content/drive/MyDrive/TavernAI/User Avatars/"):
    os.mkdir("/content/drive/MyDrive/TavernAI/User Avatars/")
else:
  if not os.path.exists("/content/drive"):
    os.mkdir("/content/drive")
  if not os.path.exists("/content/drive/MyDrive/"):
    os.mkdir("/content/drive/MyDrive/")
#TavernAI
# %cd /
# !node -v
# !git clone https://github.com/TavernAI/TavernAIColab
# %cd /TavernAIColab/
# !npm install
time.sleep(1)

#CHARCOPY
if use_google_drive:
  src_folder = "/TavernAIColab/public/characters"
  dst_folder = "/content/drive/MyDrive/TavernAI/characters"
  for filename in os.listdir(src_folder):
    src_file = os.path.join(src_folder, filename)
    dst_file = os.path.join(dst_folder, filename)

    if os.path.exists(dst_file):
      print(f"{dst_file} already exists. Skipping...")
      continue

    shutil.copy(src_file, dst_folder)
    print(f"{src_file} copied to {dst_folder}")

# FunkEngine2023 construction |||Oh how simple it all seemed when I started.|||
if use_google_drive:
  # %env googledrive=2
  # %cd '/TavernAIColab/public/User Avatars/'
  print('Moving Avatar(s).')
  # %cd '/TavernAIColab/public/User Avatars/'
  # !cp -f -v *.* '/content/drive/MyDrive/TavernAI/User Avatars'
  # %cd '/content/drive/MyDrive/TavernAI/User Avatars/'
  # !cp -f -v -r *.* '/TavernAIColab/public/User Avatars/'
  # %cd /
  print('Moving settings.')
  if not os.path.isfile("/content/drive/MyDrive/TavernAI/settings.json"):
    # !cp -f -p "/TavernAIColab/public/settings.json" "/content/drive/MyDrive/TavernAI/settings.json"
  # %cd TavernAIColab
  print('Linking Settings.')
  if os.path.isfile("/content/drive/MyDrive/TavernAI/settings.json"):
    # !rm -f "/TavernAIColab/public/settings.json"
    # !ln -fs "/content/drive/MyDrive/TavernAI/settings.json" "/TavernAIColab/public/settings.json"
  print('Moving Config.')
  if not os.path.isfile("/content/drive/MyDrive/TavernAI/config.conf"):
    # !cp -f -p "/TavernAIColab/config.conf" "/content/drive/MyDrive/TavernAI/config.conf"
  print('Linking Config.')
  if os.path.isfile("/content/drive/MyDrive/TavernAI/config.conf"):
    # !rm -f "/TavernAIColab/config.conf"
    # !ln -fs "/content/drive/MyDrive/TavernAI/config.conf" "/TavernAIColab/config.conf"
# %cd /TavernAIColab/
# !nohup node server.js > tai.txt 2>&1 & echo -n $! > taipid.txt
time.sleep(6)
taiurl = open("tai.txt")
print(taiurl.read())
print("That is not your link.")
print("But it means your Tavern is spinning up.")
print("Soon.(tm)")
taipid = open("taipid.txt").readline()
print(taipid)
# %cd /content/
#Kobold Models
if colab_type == 2:
  if Model == "Nerys V2 6B":
    Model = "KoboldAI/OPT-6B-nerys-v2"
    path = ""
    download = ""
  elif Model == "Nerybus 6B":
    Model = "KoboldAI/OPT-6.7B-Nerybus-Mix"
    path = ""
    download = ""
  elif Model == "Erebus 6B":
    Model = "KoboldAI/OPT-6.7B-Erebus"
    path = ""
    download = ""

  if Provider == "Localtunnel":
    tunnel = "--localtunnel yes"
  else:
    tunnel = ""

  if os.path.isfile("/content/KoboldAI-Client/cloudflare.log"):
    time.sleep(1)
    # !rm -rf /content/KoboldAI-Client/cloudflare.log  

  #Henk's KoboldAI script
  # !wget https://koboldai.org/ckds && chmod +x ckds
  # !./ckds --init only
  if Provider == "Localtunnel":
    p = subprocess.Popen(['/content/ckds', '--model', Model, '--localtunnel', 'yes', '--savemodel', '--colab'], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
  else:
    p = subprocess.Popen(['/content/ckds', '--model', Model, '--savemodel', '--colab'], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
  #Do not repeat! Tricks performed by a professional!
  while True:
      line = p.stdout.readline().decode().strip()
      if "KoboldAI has finished loading and is available at the following link: " in line:
          url = open("/content/KoboldAI-Client/cloudflare.log").readline().split("KoboldAI has finished loading and is available at the following link : ")[1]
          print("KoboldAI")
          print("KoboldAI")
          print("KoboldAI")
          print(url)
          print("KoboldAI")
          print("KoboldAI")
          print("KoboldAI")
          break
      if "KoboldAI has finished loading and is available at the following link for UI 1: " in line:
          url = open("/content/KoboldAI-Client/cloudflare.log").readline().split("KoboldAI has finished loading and is available at the following link : ")[1]
          print("KoboldAI")
          print("KoboldAI")
          print("KoboldAI")
          print(url)
          print("KoboldAI")
          print("KoboldAI")
          print("KoboldAI")
          break
      if not line:
          break
      print(url)
      if "INIT" in line and "Transformers" in line:
        print("Model loading to VRAM.")
        print("In the meanwhile...")
        print("TavernAI is ready!")
        print("Click the link.")
        print("TavernAI")
        print("TavernAI")
        print("TavernAI")
        print(lturl)
        print("TavernAI")
        print("TavernAI")
        print("TavernAI")
        print("Not much else to do...")
        print("For the next 4-6 minutes")
        print("Hurry up and wait.")
  else:
    print("STOP WAITING!")
  print('KoboldAI LINK:')
  print(url)
  # %env colaburl=url
  print(url)
  print("")
  print("")
  print(lturl)
  print("")
  print("")
  print("TAVERN!")
  print(lturl)
  print("TAVERN!")
  print("")
  print("")

print("")
print("TAVERN!")
print(lturl)
print(ltpid)
print("TAVERN!")
print("")
print("")
print("")
print("")
print("")
print("")
print("")
print("IF YOU CAME BACK FROM YOUR TAVERN TAB FOR YOUR KOBOLD-API URL IT SHOULD APPEAR BELOW")
if os.path.isfile("/content/KoboldAI-Client/cloudflare.log"):
  time.sleep(1)
  kobold = open("/content/KoboldAI-Client/cloudflare.log").readline()
  time.sleep(1)
  print(kobold)
print("")
print("")
print("")
print(url)
print("LAST CHANCE FOR KOBOLD!")
print(url)
print("KOBOLD DOESN'T HAVE TO GO HOME BUT IT CAN'T STAY HERE!")
print("")
print("")
print("IF YOU SELECTED 'NO MODEL' OR 'KOBOLD HORDE' YOU ALREADY HAVE THE ONLY LINK YOU NEED.")
print("")
print("")

print("For those of you here to use an OpenAI or NovelAI LLM, you already know the drill...")
print('###########################################################################################################')
print('###########################################################################################################')
print('#:::########: ##:::: ##: ##::: ##: ##::: ##: ########: ##::: ##:: ######::: ####: ##::: ##: ########: ####:')
print('#:: ##.....:: ##:::: ##: ###:: ##: ##:: ##:: ##.....:: ###:: ##: ##... ##::. ##:: ###:: ##: ##.....:: ####:')
print('#:: ##::::::: ##:::: ##: ####: ##: ##: ##::: ##::::::: ####: ##: ##:::..:::: ##:: ####: ##: ##::::::: ####:')
print('#:: ######::: ##:::: ##: ## ## ##: #####:::: ######::: ## ## ##: ##:: ####:: ##:: ## ## ##: ######:::: ##::')
print('#:: ##...:::: ##:::: ##: ##. ####: ##. ##::: ##...:::: ##. ####: ##::: ##::: ##:: ##. ####: ##...:::::..:::')
print('#:: ##::::::: ##:::: ##: ##:. ###: ##:. ##:: ##::::::: ##:. ###: ##::: ##::: ##:: ##:. ###: ##::::::: ####:')
print('#:: ##:::::::. #######:: ##::. ##: ##::. ##: ########: ##::. ##:. ######::: ####: ##::. ##: ########: ####:')
print('#::..:::::::::.......:::..::::..::..::::..::........::..::::..:::......::::....::..::::..::........::....::')
print('###########################################################################################################')
print('###########################################################################################################')
print('#.##::::::::::::::::::: ########: ##:::: ##: ##::: ##: ##::: ##::::::::::::::::::: ##:')
print('#.##::::::::::::::::::: ##.....:: ##:::: ##: ###:: ##: ##:: ##:::::::::::::::::::: ##:')
print('#.##::::::::::::::::::: ##::::::: ##:::: ##: ####: ##: ##: ##::::::::::::::::::::: ##:')
print('#.##::::::::::::::::::: ######::: ##:::: ##: ## ## ##: #####:::::::::::::::::::::: ##:')
print('#.##::::::::::::::::::: ##...:::: ##:::: ##: ##. ####: ##. ##::::::::::::::::::::: ##:')
print('#.##::::::::::::::::::: ##::::::: ##:::: ##: ##:. ###: ##:. ##:::::::::::::::::::: ##:')
print('#.##::::::::::::::::::: ##:::::::. #######:: ##::. ##: ##::. ##::::::::::::::::::: ##:')
print('#.##:::::::::::::::::::..:::::::::.......:::..::::..::..::::..:::::::::::::::::::: ##:')
print('#.##:::::::::: ########: ##::: ##:: ######::: ####: ##::: ##: ########: ####:::::: ##:')
print('#.##:::::::::: ##.....:: ###:: ##: ##... ##::. ##:: ###:: ##: ##.....:: ####:::::: ##:')
print('#.##:::::::::: ##::::::: ####: ##: ##:::..:::: ##:: ####: ##: ##::::::: ####:::::: ##:')
print('#.##:::::::::: ######::: ## ## ##: ##:: ####:: ##:: ## ## ##: ######:::: ##::::::: ##:')
print('#.##:::::::::: ##...:::: ##. ####: ##::: ##::: ##:: ##. ####: ##...:::::..:::::::: ##:')
print('#.##:::::::::: ##::::::: ##:. ###: ##::: ##::: ##:: ##:. ###: ##::::::: ####:::::: ##:')
print('#.##:::::::::: ########: ##::. ##:. ######::: ####: ##::. ##: ########: ####:::::: ##:')
print('#.##::::::::::........::..::::..:::......::::....::..::::..::........::....::::::: ##:')
print('###########################################################################################################')
print('###########################################################################################################')
print('#:::########: ##:::: ##: ##::: ##: ##::: ##: ########: ##::: ##:: ######::: ####: ##::: ##: ########: ####:')
print('#:: ##.....:: ##:::: ##: ###:: ##: ##:: ##:: ##.....:: ###:: ##: ##... ##::. ##:: ###:: ##: ##.....:: ####:')
print('#:: ##::::::: ##:::: ##: ####: ##: ##: ##::: ##::::::: ####: ##: ##:::..:::: ##:: ####: ##: ##::::::: ####:')
print('#:: ######::: ##:::: ##: ## ## ##: #####:::: ######::: ## ## ##: ##:: ####:: ##:: ## ## ##: ######:::: ##::')
print('#:: ##...:::: ##:::: ##: ##. ####: ##. ##::: ##...:::: ##. ####: ##::: ##::: ##:: ##. ####: ##...:::::..:::')
print('#:: ##::::::: ##:::: ##: ##:. ###: ##:. ##:: ##::::::: ##:. ###: ##::: ##::: ##:: ##:. ###: ##::::::: ####:')
print('#:: ##:::::::. #######:: ##::. ##: ##::. ##: ########: ##::. ##:. ######::: ####: ##::. ##: ########: ####:')
print('#::..:::::::::.......:::..::::..::..::::..::........::..::::..:::......::::....::..::::..::........::....::')
print('###########################################################################################################')
print('###########################################################################################################')
# !curl ipecho.net/plain
# !curl ipecho.net/plain
# !curl ipecho.net/plain
# !curl ipecho.net/plain
# !curl ipecho.net/plain
# !curl ipecho.net/plain
print("Mystery decoder sequence for localtunnel issues...")
# !curl ipecho.net/plain
# !curl ipecho.net/plain
# !curl ipecho.net/plain
# !curl ipecho.net/plain
# !curl ipecho.net/plain
# !curl ipecho.net/plain
print("Seriously stop asking how to do it...")
# !curl ipecho.net/plain
# !curl ipecho.net/plain
# !curl ipecho.net/plain
# !curl ipecho.net/plain
# !curl ipecho.net/plain
# !curl ipecho.net/plain
# !curl ipecho.net/plain
# !curl ipecho.net/plain
# !curl ipecho.net/plain
# !curl ipecho.net/plain
# !curl ipecho.net/plain
# !curl ipecho.net/plain
# !curl ipecho.net/plain
# !curl ipecho.net/plain
# !curl ipecho.net/plain
# !curl ipecho.net/plain
# !curl ipecho.net/plain
# !curl ipecho.net/plain
# !curl ipecho.net/plain
print("")
print("IF YOU CAME BACK FROM YOUR TAVERN TAB FOR YOUR KOBOLD-API URL IT SHOULD APPEAR BELOW")
if os.path.isfile("/content/KoboldAI-Client/cloudflare.log"):
  time.sleep(1)
  kobold = open("/content/KoboldAI-Client/cloudflare.log").readline()
  time.sleep(1)
  print(kobold)
print("TavernAI, again...")
print(lturl)
print("")
print("")
print("")

# !curl ipecho.net/plain
# !curl ipecho.net/plain
# !curl ipecho.net/plain
# !curl ipecho.net/plain

ltpid = open("/ltpid.txt").readline()
lturl = open("/lt.txt").readline().strip().split("your url is: ")[1]
taiurl = open("/TavernAIColab/tai.txt")
print(taiurl.read())
print("NOT YOUR LINK TO USE!")
print("Tavern is Taverning...")
print("What follows are the pids of the tunnel into Tavern, and Tavern's node.js runtime")
taipid = open("taipid.txt").readline()
print(taipid)

# %%
#@title
# !curl ipecho.net/plain
